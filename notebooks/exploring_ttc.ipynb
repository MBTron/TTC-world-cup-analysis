# %% [markdown]
# ## Pulling TTC data
#
# Data contains:
# - All TTC transportation modes (subway, streetcars, and buses)
# - Scheduling information (route definitions, stop patterns, stop locations, and schedules)

# %% [markdown]
# ### Getting URL

# %%
import requests
	
# Toronto Open Data is stored in a CKAN instance. It's APIs are documented here:
# https://docs.ckan.org/en/latest/api/
	
# To hit our API, you'll be making requests to:
base_url = "https://ckan0.cf.opendata.inter.prod-toronto.ca"
		
# Datasets are called "packages". Each package can contain many "resources"
# To retrieve the metadata for this package and its resources, use the package name in this page's URL:	
url = base_url + "/api/3/action/package_show"
params = { "id": "merged-gtfs-ttc-routes-and-schedules"}
package = requests.get(url, params = params).json()
# Out:
# /Users/michaelb/Documents/Code Projects/ttc-transit-data/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# let's see what's available
for resource in package["result"]["resources"]:
    print(f"Resource name: {resource['name']}")
    print(f"Resource format: {resource['format']}")
    print(f"Resource url: {resource['url']}")
    print(f"Last updated: {resource['last_modified']}")
# Out:
# Resource name: Complete GTFS
# Resource format: ZIP
# Resource url: https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/b811ead4-6eaf-4adb-8408-d389fb5a069c/resource/c920e221-7a1c-488b-8c5b-6d8cd4e85eaf/download/completegtfs.zip
# Last updated: 2025-10-14T14:16:01

# %% [markdown]
# ### Downloading

# %%
from pathlib import Path

# set paths
PROJECT_ROOT = Path.cwd().parent

DATA_DIR = PROJECT_ROOT / "data" 
RAW_DIR = DATA_DIR / "raw"
GTFS_DIR = DATA_DIR / "gtfs"

# make dir if doesn't yet exist 
for d in [DATA_DIR, RAW_DIR, GTFS_DIR]:
    d.mkdir(parents=True, exist_ok=True)

# %%
# downlaods GTFS zip
ZIP_PATH = RAW_DIR / "ttc_gtfs.zip"

gtfs_url = None
for resource in package["result"]["resources"]:
    if resource["format"].lower() == "zip":
        gtfs_url = resource["url"]
        print("GTFS download URL:", gtfs_url)
        break

if gtfs_url:
    print(f"Downloading TTC GTFS data to {ZIP_PATH} ...")
    response = requests.get(gtfs_url)
    response.raise_for_status()  # Raises error if request fails

    with open(ZIP_PATH, "wb") as f:
        f.write(response.content)
    print("Downloaded TTC GTFS data -> ttc_gtfs.zip")
else:
    print("GTFS ZIP not found in package.")
# Out:
# GTFS download URL: https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/b811ead4-6eaf-4adb-8408-d389fb5a069c/resource/c920e221-7a1c-488b-8c5b-6d8cd4e85eaf/download/completegtfs.zip
# Downloading TTC GTFS data to /Users/michaelb/Documents/Code Projects/ttc-transit-data/data/raw/ttc_gtfs.zip ...
# Downloaded TTC GTFS data -> ttc_gtfs.zip

# %%
# verify and extract
import zipfile

print(f"📦 Extracting files to {GTFS_DIR}")
with zipfile.ZipFile(ZIP_PATH, "r") as zip_ref:
    zip_ref.extractall(GTFS_DIR)

print("✅ Extraction complete. Extracted files:")
for name in zip_ref.namelist():
    print(" -", name)
# Out:
# 📦 Extracting files to /Users/michaelb/Documents/Code Projects/ttc-transit-data/data/gtfs
# ✅ Extraction complete. Extracted files:
#  - agency.txt
#  - calendar.txt
#  - calendar_dates.txt
#  - routes.txt
#  - shapes.txt
#  - stops.txt
#  - stop_times.txt
#  - trips.txt

# %% [markdown]
# ### Exploring the data

# %%
import pandas as pd

# load GTFS tables 
stops = pd.read_csv(GTFS_DIR / "stops.txt")
routes = pd.read_csv(GTFS_DIR / "routes.txt")
trips = pd.read_csv(GTFS_DIR / "trips.txt")
stop_times = pd.read_csv(GTFS_DIR / "stop_times.txt")
calendar = pd.read_csv(GTFS_DIR / "calendar.txt")
shapes = pd.read_csv(GTFS_DIR / "shapes.txt")

# Quick check
print("Stops shape:", stops.shape)
print(stops.head())
# Out:
# C:\Users\mibruhje\AppData\Local\Temp\ipykernel_24992\2851871681.py:6: DtypeWarning: Columns (4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   trips = pd.read_csv(GTFS_DIR / "trips.txt")
# C:\Users\mibruhje\AppData\Local\Temp\ipykernel_24992\2851871681.py:7: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   stop_times = pd.read_csv(GTFS_DIR / "stop_times.txt")
# Stops shape: (9350, 12)
#    stop_id  stop_code                                 stop_name  stop_desc  \
# 0        1       7978        Millwood Rd at McRae Dr South Side        NaN
# 1        2        155                Bathurst St at Horsham Ave        NaN
# 2        3       1514          Royal York Rd at King Georges Rd        NaN
# 3        4       2593           Finch Ave West at Driftwood Ave        NaN
# 4        5       1231  Lawrence Ave East at Wanless Cres (West)        NaN
#
#     stop_lat   stop_lon  zone_id  stop_url  location_type  parent_station  \
# 0  43.704652 -79.367698      NaN       NaN            NaN             NaN
# 1  43.768449 -79.441504      NaN       NaN            NaN             NaN
# 2  43.650225 -79.512691      NaN       NaN            NaN             NaN
# 3  43.757924 -79.513523      NaN       NaN            NaN             NaN
# 4  43.727149 -79.392116      NaN       NaN            NaN             NaN
#
#    stop_timezone  wheelchair_boarding
# 0            NaN                    1
# 1            NaN                    1
# 2            NaN                    1
# 3            NaN                    1
# 4            NaN                    2
# C:\Users\mibruhje\AppData\Local\Temp\ipykernel_24992\2851871681.py:9: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   shapes = pd.read_csv(GTFS_DIR / "shapes.txt")

# %%
# number of stops 
print(f"Total stops: {stops.shape[0]}")

# Stops per route
stops_per_route = trips.merge(stop_times, on="trip_id").merge(routes, on="route_id")
stops_per_route.groupby("route_short_name")["stop_id"].nunique().sort_values(ascending=False)
# Out:
# Total stops: 9350
# route_short_name
# 300    230
# 301    210
# 52     193
# 96     192
# 501    176
#       ...
# 101     16
# 944     14
# 4       10
# 900      6
# 882      2
# Name: stop_id, Length: 224, dtype: int64

# %%
# Number of routes per mode
routes["route_type"].value_counts()
# Out:
# route_type
# 700    203
# 900     18
# 400      3
# Name: count, dtype: int64

# %%
# subway routes are 400
routes[routes['route_type']==400]
# Out:
#      route_id  agency_id  route_short_name            route_long_name  \
# 215         1          1                 1  LINE 1 (YONGE-UNIVERSITY)
# 216         2          1                 2  LINE 2 (BLOOR - DANFORTH)
# 217         4          1                 4          LINE 4 (SHEPPARD)
#
#      route_desc  route_type  route_url route_color route_text_color
# 215         NaN         400        NaN      D5C82B           000000
# 216         NaN         400        NaN      008000           FFFFFF
# 217         NaN         400        NaN      B300B3           FFFFFF

# %%
# Trips per day (approx - looking at Monday for e.g.)
service_ids = calendar[calendar["monday"]==1]['service_id'] # filer for services that run on Mon
daily_trips = trips[trips['service_id'].isin(service_ids)] # only trips on Monday
daily_trips.groupby("route_id").size().sort_values(ascending=False)
# Out:
# route_id
# 504    1656
# 36     1323
# 63     1274
# 47     1186
# 32     1015
#        ...
# 404      16
# 400      14
# 405      14
# 403      12
# 882       1
# Length: 222, dtype: int64

# %%
import folium
from IPython.display import display

# Map first 50 stops
m = folium.Map(location=[43.6532, -79.3832], zoom_start=12)
for idx, row in stops.head(50).iterrows():
    folium.CircleMarker(
        location=[row.stop_lat, row.stop_lon],
        radius=3,
        color='blue',
        fill=True
    ).add_to(m)
# display(m)

# %%
routes[routes['route_id']==1]
# Out:
#      route_id  agency_id  route_short_name            route_long_name  \
# 215         1          1                 1  LINE 1 (YONGE-UNIVERSITY)
#
#      route_desc  route_type  route_url route_color route_text_color
# 215         NaN         400        NaN      D5C82B           000000

# %%
# get all stops for line 1 subway
trips_for_route = trips[trips['route_id'] == 1]

# merge with stop_times to find all stop events 
route_stop_events = stop_times.merge(
    trips_for_route[['trip_id']], 
    on='trip_id', 
    how='inner'
)

# extract list of unique stop ids
unique_stop_ids = route_stop_events['stop_id'].unique()

# filter master stops table 
final_stops_list = stops[stops['stop_id'].isin(unique_stop_ids)]
final_stops_list
# Out:
#       stop_id  stop_code                                          stop_name  \
# 8583    18373      13818            ST ANDREW STATION - SOUTHBOUND PLATFORM
# 9147    14111      14111                Finch Station - Southbound Platform
# 9148    13789      13789    North York Centre Station - Southbound Platform
# 9149    13860      13860       Sheppard-Yonge Station - Southbound Platform
# 9150    13792      13792           York Mills Station - Southbound Platform
# ...       ...        ...                                                ...
# 9291    15665      15665       Downsview Park Station - Southbound Platform
# 9292    15661      15661          Highway 407 Station - Northbound Platform
# 9293    15660      15660          Highway 407 Station - Southbound Platform
# 9294    15662      15662  Vaughan Metropolitan Centre Station - Subway P...
# 9295    15663      15663  Vaughan Metropolitan Centre Station - Southbou...
#
#       stop_desc   stop_lat   stop_lon  zone_id  stop_url  location_type  \
# 8583        NaN  43.647605 -79.385004      NaN       NaN            NaN
# 9147        NaN  43.780147 -79.415692      NaN       NaN            NaN
# 9148        NaN  43.767347 -79.412492      NaN       NaN            NaN
# 9149        NaN  43.760348 -79.410691      NaN       NaN            NaN
# 9150        NaN  43.743248 -79.405991      NaN       NaN            NaN
# ...         ...        ...        ...      ...       ...            ...
# 9291        NaN  43.753311 -79.478693      NaN       NaN            NaN
# 9292        NaN  43.783359 -79.523454      NaN       NaN            NaN
# 9293        NaN  43.783359 -79.523454      NaN       NaN            NaN
# 9294        NaN  43.794021 -79.527906      NaN       NaN            NaN
# 9295        NaN  43.794021 -79.527906      NaN       NaN            NaN
#
#       parent_station  stop_timezone  wheelchair_boarding
# 8583             NaN            NaN                    0
# 9147             NaN            NaN                    1
# 9148             NaN            NaN                    1
# 9149             NaN            NaN                    1
# 9150             NaN            NaN                    1
# ...              ...            ...                  ...
# 9291             NaN            NaN                    1
# 9292             NaN            NaN                    1
# 9293             NaN            NaN                    1
# 9294             NaN            NaN                    1
# 9295             NaN            NaN                    1
#
# [76 rows x 12 columns]

# %% [markdown]
# ### Headway calc example
#
# Let's calculate headway for route_id == 1 (I think this is the main subway line)
#
# To do this we'll:
# - join stops_time df with the trips_df b/c stops has stop time info, while trips has routeId and serviceId (day of week) info
# - convert everything to time from midnight so we can do math
# - sort the df so we do this for each service day (sort of days of week, but can run multiple overlapping services on same day)
# - calculate headway by duplicating df and shifting by 1

# %%
temp = stop_times.merge(
        trips[['trip_id', 'route_id', 'service_id']], 
        on='trip_id', 
        how='inner'
    )

# %%
temp = temp[temp['route_id']==1]

# %%
temp.sort_values(['arrival_time'])
# Out:
#            trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 4170069  131337109     05:31:21       05:31:21    14111              1
# 4170070  131337109     05:33:45       05:33:45    13789              2
# 4170071  131337109     05:35:00       05:35:00    13860              3
# 4170149  131337110     05:36:08       05:36:08    14111              1
# 4170072  131337109     05:38:06       05:38:06    13792              4
# ...            ...          ...            ...      ...            ...
# 4221806  131339169     26:30:26       26:30:26    15662             38
# 4290344  131341848     26:30:26       26:30:26    15662             38
# 4170059  131337406     26:31:52       26:31:52    15656             36
# 4170060  131337406     26:33:55       26:33:55    15661             37
# 4170061  131337406     26:35:56       26:35:56    15662             38
#
#         stop_headsign  pickup_type  drop_off_type  shape_dist_traveled  \
# 4170069           NaN            0              0                  NaN
# 4170070           NaN            0              0               1.5224
# 4170071           NaN            0              0               2.3171
# 4170149           NaN            0              0                  NaN
# 4170072           NaN            0              0               4.2739
# ...               ...          ...            ...                  ...
# 4221806           NaN            0              0              38.9837
# 4290344           NaN            0              0              38.9837
# 4170059           NaN            0              0              36.0378
# 4170060           NaN            0              0              37.4393
# 4170061           NaN            0              0              38.9837
#
#          timepoint  route_id  service_id
# 4170069        NaN         1           1
# 4170070        NaN         1           1
# 4170071        NaN         1           1
# 4170149        NaN         1           1
# 4170072        NaN         1           1
# ...            ...       ...         ...
# 4221806        NaN         1           2
# 4290344        NaN         1           4
# 4170059        NaN         1           1
# 4170060        NaN         1           1
# 4170061        NaN         1           1
#
# [71624 rows x 12 columns]

# %%
def time_to_seconds(time_str):
    if pd.isna(time_str):
        return 0 
    h, m, s = map(int, time_str.split(':'))
    return h * 3600 + m * 60 + s

temp['arrival_time_sec'] = temp['arrival_time'].apply(time_to_seconds)

# %%
temp = temp.sort_values(['service_id', 'stop_id', 'arrival_time_sec'])

# %%
temp['previous_arrival_time_sec'] = temp.groupby(['stop_id', 'service_id'])['arrival_time_sec'].shift(1)
temp['headway_sec'] = temp['arrival_time_sec'] - temp['previous_arrival_time_sec']

# %%
# Filter out the first stop in each group (which will have a NaN for headway)
headways = temp.dropna(subset=['headway_sec'])
headways
# Out:
#            trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 4170150  131337110     05:38:32       05:38:32    13789              2
# 4170568  131337111     05:43:19       05:43:19    13789              2
# 4170530  131337112     05:48:01       05:48:01    13789              2
# 4170492  131337114     05:52:43       05:52:43    13789              2
# 4170454  131337115     05:57:25       05:57:25    13789              2
# ...            ...          ...            ...      ...            ...
# 4294675  131342075     25:19:40       25:19:40    18373             21
# 4294637  131342076     25:25:40       25:25:40    18373             21
# 4294599  131342077     25:31:40       25:31:40    18373             21
# 4294561  131342078     25:37:40       25:37:40    18373             21
# 4299214  131342079     25:43:40       25:43:40    18373             21
#
#         stop_headsign  pickup_type  drop_off_type  shape_dist_traveled  \
# 4170150           NaN            0              0               1.5224
# 4170568           NaN            0              0               1.5224
# 4170530           NaN            0              0               1.5224
# 4170492           NaN            0              0               1.5224
# 4170454           NaN            0              0               1.5224
# ...               ...          ...            ...                  ...
# 4294675           NaN            0              0              22.9676
# 4294637           NaN            0              0              22.9676
# 4294599           NaN            0              0              22.9676
# 4294561           NaN            0              0              22.9676
# 4299214           NaN            0              0              22.9676
#
#          timepoint  route_id  service_id  arrival_time_sec  \
# 4170150        NaN         1           1             20312
# 4170568        NaN         1           1             20599
# 4170530        NaN         1           1             20881
# 4170492        NaN         1           1             21163
# 4170454        NaN         1           1             21445
# ...            ...       ...         ...               ...
# 4294675        NaN         1           4             91180
# 4294637        NaN         1           4             91540
# 4294599        NaN         1           4             91900
# 4294561        NaN         1           4             92260
# 4299214        NaN         1           4             92620
#
#          previous_arrival_time_sec  headway_sec
# 4170150                    20025.0        287.0
# 4170568                    20312.0        287.0
# 4170530                    20599.0        282.0
# 4170492                    20881.0        282.0
# 4170454                    21163.0        282.0
# ...                            ...          ...
# 4294675                    90820.0        360.0
# 4294637                    91180.0        360.0
# 4294599                    91540.0        360.0
# 4294561                    91900.0        360.0
# 4299214                    92260.0        360.0
#
# [71320 rows x 15 columns]

# %%
# aggregate to get stop-level stats
stop_stats = headways.groupby('stop_id').agg(
    avg_headway_minutes = ('headway_sec', lambda x : x.mean() / 60),
    median_headway_minutes = ('headway_sec', lambda x: x.median() / 60),
    total_trips_served=('trip_id', 'count')
).reset_index()

# %%
# add stop names 
stop_stats = stop_stats.merge(
    stops[['stop_id', 'stop_name']], 
    on='stop_id', 
    how='left'
).drop_duplicates(subset=['stop_id'])

# %%
stop_stats
# Out:
#     stop_id  avg_headway_minutes  median_headway_minutes  total_trips_served  \
# 0     13789             4.904202                4.566667                 936
# 1     13790             4.849146                4.566667                 976
# 2     13791             4.849146                4.566667                 976
# 3     13792             4.904006                4.550000                 936
# 4     13793             4.904024                4.558333                 936
# ..      ...                  ...                     ...                 ...
# 71    15664             4.951775                4.566667                 967
# 72    15665             5.214212                5.000000                 876
# 73    15666             4.951775                4.550000                 967
# 74    15667             5.214593                5.000000                 876
# 75    18373             4.911757                4.566667                 937
#
#                                           stop_name
# 0   North York Centre Station - Southbound Platform
# 1   North York Centre Station - Northbound Platform
# 2          York Mills Station - Northbound Platform
# 3          York Mills Station - Southbound Platform
# 4            Lawrence Station - Southbound Platform
# ..                                              ...
# 71     Downsview Park Station - Northbound Platform
# 72     Downsview Park Station - Southbound Platform
# 73            York University - Northbound Platform
# 74            York University - Southbound Platform
# 75          ST ANDREW STATION - SOUTHBOUND PLATFORM
#
# [76 rows x 5 columns]

# %% [markdown]
# ### Route geometries

# %%
shapes.head()
# Out:
#      shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence  \
# 0  shp-100-02     43.677011    -79.358044                  1
# 1  shp-100-02     43.676933    -79.358197                  2
# 2  shp-100-02     43.676855    -79.358351                  3
# 3  shp-100-02     43.676784    -79.358457                  4
# 4  shp-100-02     43.676712    -79.358563                  5
#
#    shape_dist_traveled
# 0                 0.00
# 1                15.08
# 2                30.16
# 3                41.80
# 4                53.44
